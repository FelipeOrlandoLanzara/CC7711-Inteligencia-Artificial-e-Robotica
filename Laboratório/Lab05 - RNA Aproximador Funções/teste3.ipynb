# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import MaxAbsScaler

# %%
# ----- SIMULAÇÃO 01 ----- #

# Carregando Arquivo de teste
print('Carregando Arquivo de teste')
arquivo = np.load('teste3.npy')
x = arquivo[0]

scale = MaxAbsScaler().fit(arquivo[1])
y = np.ravel(scale.transform(arquivo[1]))

# Definindo o número de iterações
iteracoes = 1000

erros = []
# Repetir o processo 10 vezes
for i in range(10):
  print(f'Treinando RNA - Iteração {i+1}')

  # Criando e treinando o modelo
  regr = MLPRegressor(hidden_layer_sizes=(10, 5),
                      max_iter=iteracoes,
                      activation='tanh',  # {'identity', 'logistic', 'tanh', 'relu'}
                      solver='adam',  # {'lbfgs', 'sgd', 'adam'}
                      learning_rate='adaptive',
                      n_iter_no_change=iteracoes,
                      verbose=False)

  regr.fit(x, y)

  # Predição
  y_est = regr.predict(x)

  plt.figure(figsize=[14, 5])

  # Plot da função original
  plt.subplot(1, 3, 1)
  plt.title('Função Original')
  plt.plot(x, y, color='green')

  # Plot do erro
  plt.subplot(1,3,2)
  plt.title('Curva erro (%s)' % str(round(regr.best_loss_,5)))
  erros.append(regr.best_loss_)
  plt.plot(regr.loss_curve_,color='red')
  print(regr.best_loss_)

  # Plot da função original e aproximada
  plt.subplot(1, 3, 3)
  plt.title('Função Original x Função aproximada')
  plt.plot(x, y, linewidth=1, color='green')
  plt.plot(x, y_est, linewidth=2, color='blue')

  # Mostrar o gráfico
  plt.show()

array_erros = np.array(erros)
media_erros = np.mean(array_erros)
desvio_erros = np.std(array_erros)
menor_erro = np.min(array_erros)

print(f"Média de erros: {media_erros}")
print(f'Desvio padrão erros: {desvio_erros:.10f}')
print(f'Menor valor de erro: {menor_erro}')
# Out:
# Carregando Arquivo de teste
# Treinando RNA - Iteração 1
# 0.005957515772000217
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 2
# 0.003402899982983152
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 3
# 0.0012101801894799367
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 4
# 0.015568036477359071
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 5
# 0.007777257789141176
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 6
# 0.004327557971919935
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 7
# 0.01123724388687463
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 8
# 0.00250643690037773
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 9
# 0.0024738401360261766
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 10
# 0.001224503343320553
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Média de erros: 0.005568547244948258
# Desvio padrão erros: 0.0044744106
# Menor valor de erro: 0.0012101801894799367

# %%
# ----- SIMULAÇÃO 02 ----- #

# Carregando Arquivo de teste
print('Carregando Arquivo de teste')
arquivo = np.load('teste3.npy')
x = arquivo[0]

scale = MaxAbsScaler().fit(arquivo[1])
y = np.ravel(scale.transform(arquivo[1]))

# Definindo o número de iterações
iteracoes = 1000

erros = []
# Repetir o processo 10 vezes
for i in range(10):
  print(f'Treinando RNA - Iteração {i+1}')

  # Criando e treinando o modelo
  regr = MLPRegressor(hidden_layer_sizes=(20, 10),
                      max_iter=iteracoes,
                      activation='tanh',  # {'identity', 'logistic', 'tanh', 'relu'}
                      solver='adam',  # {'lbfgs', 'sgd', 'adam'}
                      learning_rate='adaptive',
                      n_iter_no_change=iteracoes,
                      verbose=False)

  regr.fit(x, y)

  # Predição
  y_est = regr.predict(x)

  plt.figure(figsize=[14, 5])

  # Plot da função original
  plt.subplot(1, 3, 1)
  plt.title('Função Original')
  plt.plot(x, y, color='green')

  # Plot do erro
  plt.subplot(1,3,2)
  plt.title('Curva erro (%s)' % str(round(regr.best_loss_,5)))
  erros.append(regr.best_loss_)
  plt.plot(regr.loss_curve_,color='red')
  print(regr.best_loss_)

  # Plot da função original e aproximada
  plt.subplot(1, 3, 3)
  plt.title('Função Original x Função aproximada')
  plt.plot(x, y, linewidth=1, color='green')
  plt.plot(x, y_est, linewidth=2, color='blue')

  # Mostrar o gráfico
  plt.show()

array_erros = np.array(erros)
media_erros = np.mean(array_erros)
desvio_erros = np.std(array_erros)
menor_erro = np.min(array_erros)

print(f"Média de erros: {media_erros}")
print(f'Desvio padrão erros: {desvio_erros:.10f}')
print(f'Menor valor de erro: {menor_erro}')
# Out:
# Carregando Arquivo de teste
# Treinando RNA - Iteração 1
# 0.0027242551218856705
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 2
# 0.0018810751120260415
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 3
# 0.000855207131441249
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 4
# 0.0010181390127136595
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 5
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.0009229433946351256
# Treinando RNA - Iteração 6
# 0.002066585586108847
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 7
# 0.002563229546385062
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 8
# 0.0035937996550929373
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 9
# 0.0016256110779227007
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 10
# 0.0008390475224833823
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Média de erros: 0.0018089893160694675
# Desvio padrão erros: 0.0008920945
# Menor valor de erro: 0.0008390475224833823

# %%
# ----- TESTE 3 ----- #

# Carregando Arquivo de teste
print('Carregando Arquivo de teste')
arquivo = np.load('teste3.npy')
x = arquivo[0]

scale = MaxAbsScaler().fit(arquivo[1])
y = np.ravel(scale.transform(arquivo[1]))

# Definindo o número de iterações
iteracoes = 1000

erros = []
# Repetir o processo 10 vezes
for i in range(10):
  print(f'Treinando RNA - Iteração {i+1}')

  # Criando e treinando o modelo
  regr = MLPRegressor(hidden_layer_sizes=(30, 20),
                      max_iter=iteracoes,
                      activation='tanh',  # {'identity', 'logistic', 'tanh', 'relu'}
                      solver='adam',  # {'lbfgs', 'sgd', 'adam'}
                      learning_rate='adaptive',
                      n_iter_no_change=iteracoes,
                      verbose=False)

  regr.fit(x, y)

  # Predição
  y_est = regr.predict(x)

  plt.figure(figsize=[14, 5])

  # Plot da função original
  plt.subplot(1, 3, 1)
  plt.title('Função Original')
  plt.plot(x, y, color='green')

  # Plot do erro
  plt.subplot(1,3,2)
  plt.title('Curva erro (%s)' % str(round(regr.best_loss_,5)))
  erros.append(regr.best_loss_)
  plt.plot(regr.loss_curve_,color='red')
  print(regr.best_loss_)

  # Plot da função original e aproximada
  plt.subplot(1, 3, 3)
  plt.title('Função Original x Função aproximada')
  plt.plot(x, y, linewidth=1, color='green')
  plt.plot(x, y_est, linewidth=2, color='blue')

  # Mostrar o gráfico
  plt.show()

array_erros = np.array(erros)
media_erros = np.mean(array_erros)
desvio_erros = np.std(array_erros)
menor_erro = np.min(array_erros)

print(f"Média de erros: {media_erros}")
print(f'Desvio padrão erros: {desvio_erros:.10f}')
print(f'Menor valor de erro: {menor_erro}')
# Out:
# Carregando Arquivo de teste
# Treinando RNA - Iteração 1
# 0.0009267185177273069
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 2
# 0.0005855450161780564
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 3
# 0.0008310104684356134
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 4
# 0.0004966920732888968
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 5
# 0.000777369994684665
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 6
# 0.0006336571920264717
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 7
# 0.0004610446305975839
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 8
# 0.0007608386495904136
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 9
# 0.0006859078935050236
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Treinando RNA - Iteração 10
# c:\Users\felip\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.0009764920937673594
# Média de erros: 0.0007135276529801391
# Desvio padrão erros: 0.0001640134
# Menor valor de erro: 0.0004610446305975839
